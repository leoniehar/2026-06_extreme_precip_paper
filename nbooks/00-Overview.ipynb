# %% [markdown]
# # Overview of Jupyter Notebooks and Utilities Applied to Generate Paper Plots

# %% [markdown]
# Here, we list all jupyter notebooks that have been run to plot all figures of the paper:
#
# Hartog et al. **Fewer but More Intense: Changes in Extreme Precipitation Cells from Global Kilometer-Scale Climate Modeling** to be submitted to ???
#
# Preprint is available under ???

# %% [markdown]
# ## Project Structure

# %% [markdown]
# * The *images* are locally hosted under

# %%
# %%bash
#
# ls ../paper-pics/
# Out:
# Fig01.jpg
# Fig02.jpg
# Fig03.jpg

# %% [markdown]
# * and all *jupyter notebooks* are stored here

# %%
# %%bash
#
# ls .
# Out:
# 00-Overview.ipynb
# 01-Plot-and-Analyse-Monthly-Precip-Stats.ipynb
# 02-Plot-Precip-Segmentation-Example.ipynb
# 03-Plotting-Slopes.ipynb

# %% [markdown]
# * Finally, these *model data* need to be available (Download them via [zenodo.org](zenodo.org)):
#     - name data here

# %% [markdown]
# ## Figure 1: Amount Accumulations and Distributions

# %% [markdown]
# ![Figure 1](../paper-pics/Fig01.jpg)
#
# **Caption:**  ????

# %% [markdown]
# - figure is prepared in  [01-Plot-and-Analyse-Monthly-Precip-Stats.ipynb](01-Plot-and-Analyse-Monthly-Precip-Stats.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 2: Segmentation Example

# %% [markdown]
# ![Figure 2](../paper-pics/Fig02.jpg)
#
# **Caption:** ???

# %% [markdown]
# - figure is prepared in  [02-Plot-Precip-Segmentation-Example.ipynb](02-Plot-Precip-Segmentation-Example.ipynb)

# %% [markdown]
# ## Figure 3: Trends

# %% [markdown]
# ![Figure 3](../paper-pics/Fig03.jpg)
#
# **Caption:** ???

# %% [markdown]
# - figure is prepared in  [03-Plotting-Slopes.ipynb](03-Plotting-Slopes.ipynb)
